# %%
import pandas as pd

# %%
df=pd.read_csv('DataAnalyst.csv')
df.head()
# Out:
#    Unnamed: 0                                          Job Title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
# 1           1                               Quality Data Analyst
# 2           2  Senior Data Analyst, Insights & Analytics Team...
# 3           3                                       Data Analyst
# 4           4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
# ...

# %% [markdown]
# **Select only the Rating column.**

# %%
df.Rating
# Out:
# 0       3.2
# 1       3.8
# 2       3.4
# 3       4.1
# 4       3.9
#        ...
# 2248    2.5
# 2249    2.9
# 2250   -1.0
# 2251    3.1
# 2252    3.4
# Name: Rating, Length: 2253, dtype: float64

# %%
df.shape[0]
# Out:
# 2253

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2253 entries, 0 to 2252
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         2253 non-null   int64
#  1   Job Title          2253 non-null   object
#  2   Salary Estimate    2253 non-null   object
#  3   Job Description    2253 non-null   object
#  4   Rating             2253 non-null   float64
#  5   Company Name       2252 non-null   object
#  6   Location           2253 non-null   object
#  7   Headquarters       2253 non-null   object
#  8   Size               2253 non-null   object
#  9   Founded            2253 non-null   int64
#  10  Type of ownership  2253 non-null   object
#  11  Industry           2253 non-null   object
#  12  Sector             2253 non-null   object
#  13  Revenue            2253 non-null   object
#  14  Competitors        2253 non-null   object
#  15  Easy Apply         2253 non-null   object
# ...

# %% [markdown]
# **View only the columns 'Job Title', 'Salary Estimate', 'Headquarters', 'Rating' and assign them to a dataframe called discipline**

# %%
discipline = df[['Job Title', 'Salary Estimate', 'Headquarters', 'Rating']]
discipline
# Out:
#                                               Job Title  \
# 0     Data Analyst, Center on Immigration and Justic...
# 1                                  Quality Data Analyst
# 2     Senior Data Analyst, Insights & Analytics Team...
# 3                                          Data Analyst
# 4                                Reporting Data Analyst
# ...                                                 ...
# 2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249              Senior Data Analyst (Corporate Audit)
# 2250  Technical Business Analyst (SQL, Data analytic...
# 2251                Data Analyst 3, Customer Experience
# 2252                        Senior Quality Data Analyst
#
#                   Salary Estimate      Headquarters  Rating
# 0      $37K-$66K (Glassdoor est.)      New York, NY     3.2
# 1      $37K-$66K (Glassdoor est.)      New York, NY     3.8
# 2      $37K-$66K (Glassdoor est.)      New York, NY     3.4
# ...

# %% [markdown]
# **Sort the Job Title by Salary Estimate, then to Headquarters**

# %%
discipline.sort_values(['Salary Estimate', 'Headquarters'], ascending = False)
# Out:
#                                       Job Title               Salary Estimate  \
# 2149  Configuration/Data Management Analyst III                            -1
# 1936                               Data Analyst   $99K-$178K (Glassdoor est.)
# 1939                        Senior Data Analyst   $99K-$178K (Glassdoor est.)
# 1927                               Data Analyst   $99K-$178K (Glassdoor est.)
# 1916                               Data Analyst   $99K-$178K (Glassdoor est.)
# ...                                         ...                           ...
# 1477                               Data Analyst  $110K-$190K (Glassdoor est.)
# 1468                               Data Analyst  $110K-$190K (Glassdoor est.)
# 1488                               Data Analyst  $110K-$190K (Glassdoor est.)
# 1479                               Data Analyst  $110K-$190K (Glassdoor est.)
# 1493     Data Analyst with Data Mapping and API  $110K-$190K (Glassdoor est.)
#
#            Headquarters  Rating
# ...

# %% [markdown]
# **Calculate the mean Rating given per Team**

# %%
round(discipline['Rating'].mean())
# Out:
# 3

# %% [markdown]
# **Filter Job Title that scored more than 3 Rating**

# %%
df[df.Rating > 3]
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0  Data Analyst, Center on Immigration and Justic...
# 1              1                               Quality Data Analyst
# 2              2  Senior Data Analyst, Insights & Analytics Team...
# 3              3                                       Data Analyst
# 4              4                             Reporting Data Analyst
# ...          ...                                                ...
# 2238        2238                       Senior Contract Data Analyst
# 2242        2242                      Business Systems Analyst-Data
# 2247        2247  Marketing/Communications - Data Analyst-Marketing
# 2251        2251                Data Analyst 3, Customer Experience
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# ...

# %% [markdown]
# **Select the Headquarters that start with W**

# %%
df[df.Headquarters.str.startswith('W')]
# Out:
#       Unnamed: 0                                          Job Title  \
# 18            18                            DATA PROGRAMMER/ANALYST
# 23            23                                       Data Analyst
# 29            29                                       Data Analyst
# 37            37  Data Analyst with Excel/DAX/ PowerBI experienc...
# 39            39                                       Data Analyst
# ...          ...                                                ...
# 2221        2221                                Data Analyst Junior
# 2226        2226                              Data Analyst - Junior
# 2236        2236                   Senior Health Data Analyst (SAS)
# 2242        2242                      Business Systems Analyst-Data
# 2251        2251                Data Analyst 3, Customer Experience
#
#                   Salary Estimate  \
# 18     $37K-$66K (Glassdoor est.)
# 23     $37K-$66K (Glassdoor est.)
# 29     $37K-$66K (Glassdoor est.)
# ...

# %% [markdown]
# **Select the first 7 columns**

# %%
# use .iloc to slices via the position of the passed integers
# : means all, 0:7 means from 0 to 7

df.iloc[: , 0:7]
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0  Data Analyst, Center on Immigration and Justic...
# 1              1                               Quality Data Analyst
# 2              2  Senior Data Analyst, Insights & Analytics Team...
# 3              3                                       Data Analyst
# 4              4                             Reporting Data Analyst
# ...          ...                                                ...
# 2248        2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2250        2250  Technical Business Analyst (SQL, Data analytic...
# 2251        2251                Data Analyst 3, Customer Experience
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# ...

# %% [markdown]
# **Select all columns except the last 3.**

# %%
# use negative to exclude the last 3 columns

df.iloc[: , :-3]
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0  Data Analyst, Center on Immigration and Justic...
# 1              1                               Quality Data Analyst
# 2              2  Senior Data Analyst, Insights & Analytics Team...
# 3              3                                       Data Analyst
# 4              4                             Reporting Data Analyst
# ...          ...                                                ...
# 2248        2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2250        2250  Technical Business Analyst (SQL, Data analytic...
# 2251        2251                Data Analyst 3, Customer Experience
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# ...

# %% [markdown]
# **Present only the Rating from New York,NY, Denver,CO and Broomfield,CO Location.**

# %%
# .loc is another way to slice, using the labels of the columns and indexes

df.loc[df.Location.isin(['New York, NY', 'Denver, CO', 'Broomfield, CO']), ['Location','Rating']]
# Out:
#             Location  Rating
# 0       New York, NY     3.2
# 1       New York, NY     3.8
# 2       New York, NY     3.4
# 3       New York, NY     4.1
# 4       New York, NY     3.9
# ...              ...     ...
# 2246      Denver, CO    -1.0
# 2247  Broomfield, CO     4.1
# 2248      Denver, CO     2.5
# 2250      Denver, CO    -1.0
# 2252  Broomfield, CO     3.4
#
# [363 rows x 2 columns]
